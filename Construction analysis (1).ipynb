# %%
# Loading the datasets
import pandas as pd
import numpy as np

### For data Visualizations
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
labourdata=pd.read_csv(r"C:\Users\nadee\Documents\Project Construction analysis\Con data.csv")

# %%
# To know the information of the data
labourdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501 entries, 0 to 500
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Employee_ID          500 non-null    float64
#  1   Employee_name        500 non-null    object
#  2   Age                  500 non-null    float64
#  3   Gender               500 non-null    object
#  4   Nationality          500 non-null    object
#  5   Native_place         500 non-null    object
#  6   Martial_status       500 non-null    object
#  7   Designation          500 non-null    object
#  8   Experience           500 non-null    float64
#  9   In_time              500 non-null    object
#  10  Out_time             500 non-null    object
#  11  Total_working_hours  500 non-null    float64
#  12  Site                 500 non-null    object
#  13  GSR_sensor           500 non-null    float64
#  14  Pulse_rate           500 non-null    float64
#  15  Body_temperature     500 non-null    float64
#  16  Calorie_brunt        500 non-null    float64
#  17  Steps_walked         500 non-null    float64
#  18  Real_time_info       500 non-null    object
#  19  Productivity         500 non-null    object
# dtypes: float64(9), object(11)
# memory usage: 78.4+ KB

# %%
# To know the shape of dataset
print("Shape of the Dataset:", labourdata.shape)
# Out:
# Shape of the Dataset: (501, 20)

# %%
# To know the head of the dataset
labourdata.head()
# Out:
#    Employee_ID     Employee_name   Age  Gender Nationality Native_place  \
# 0       1021.0     Andrea Totaro  34.0    Male      Indian        Bihar
# 1       1022.0      Minetta Tyre  45.0  Female      Indian        Bihar
# 2       1023.0  D'arcy Kamienski  44.0    Male      Indian        Bihar
# 3       1024.0   Cindie Kingcote  32.0  Female      Indian        Bihar
# 4       1025.0     Payton Ginsie  49.0    Male      Indian        Bihar
#
#   Martial_status Designation  Experience  In_time Out_time  \
# 0        Married     Skilled         3.0  8:56 AM  9:05 PM
# 1        Married     Skilled         2.0  9:17 AM  5:49 PM
# 2        Married     Skilled         0.0  8:44 AM  7:10 PM
# 3        Married     Skilled         5.0  9:18 AM  8:13 PM
# 4        Married     Skilled         4.0  7:26 AM  6:03 PM
#
#    Total_working_hours    Site  GSR_sensor  Pulse_rate  Body_temperature  \
# 0                  8.0  Site A        12.0        81.0             100.0
# 1                  7.0  Site A        18.0       105.0              99.0
# 2                  9.0  Site A        23.0        89.0              98.0
# 3                  8.0  Site A        14.0        90.0              99.0
# 4                  9.0  Site A        38.0        98.0              99.0
#
#    Calorie_brunt  Steps_walked Real_time_info Productivity
# 0         3690.0       12453.0       Standing    Excellent
# 1         2525.0       12642.0       Standing    Excellent
# 2         4895.0       14132.0       Standing    Excellent
# 3         3538.0       10002.0       Standing    Excellent
# 4         4723.0        9797.0       Standing    Excellent

# %%
# To know the Names of Each Column in Dataset
labourdata.columns
# Out:
# Index(['Employee_ID', 'Employee_name', 'Age', 'Gender', 'Nationality',
#        'Native_place', 'Martial_status', 'Designation', 'Experience',
#        'In_time', 'Out_time', 'Total_working_hours', 'Site', 'GSR_sensor',
#        'Pulse_rate', 'Body_temperature', 'Calorie_brunt', 'Steps_walked',
#        'Real_time_info', 'Productivity'],
#       dtype='object')

# %%
# From The Dataset Dropping the Unnecessary Columns
labourdata.drop(['Employee_ID','Employee_name'],axis=1, inplace=True)

# %%
#  Checking the Dataset After Dropping the Columns
labourdata.columns
# Out:
# Index(['Age', 'Gender', 'Nationality', 'Native_place', 'Martial_status',
#        'Designation', 'Experience', 'In_time', 'Out_time',
#        'Total_working_hours', 'Site', 'GSR_sensor', 'Pulse_rate',
#        'Body_temperature', 'Calorie_brunt', 'Steps_walked', 'Real_time_info',
#        'Productivity'],
#       dtype='object')

# %%
# Let's Check the Age present in this Dataset
labourdata['Age'].value_counts()
# Out:
# 33.0    22
# 26.0    20
# 45.0    20
# 51.0    20
# 25.0    18
# 55.0    18
# 34.0    17
# 37.0    17
# 59.0    17
# 39.0    17
# 27.0    16
# 48.0    16
# 30.0    16
# 58.0    14
# 56.0    14
# 50.0    14
# 49.0    14
# 57.0    13
# 60.0    13
# 41.0    13
# 47.0    13
# 42.0    12
# 32.0    12
# 44.0    12
# 53.0    12
# 38.0    12
# 54.0    12
# 40.0    11
# 31.0    11
# 36.0    11
# 52.0    10
# 43.0    10
# 46.0    10
# 35.0    10
# 28.0     7
# 29.0     6
# Name: Age, dtype: int64

# %%
# Let's Check the Gender present in this Dataset
labourdata['Gender'].value_counts()
# Out:
# Female    259
# Male      241
# Name: Gender, dtype: int64

# %%
# Let's Check the Nationality present in this Dataset
labourdata['Nationality'].value_counts()
# Out:
# Indian     181
# China      132
# African    108
# Japan       79
# Name: Nationality, dtype: int64

# %%
# Let's Check the Designation present in this Dataset
labourdata['Designation'].value_counts()
# Out:
# Skilled       307
# Un Skilled    193
# Name: Designation, dtype: int64

# %%
# Lets Check The Pulse rate Present in the Dataset
labourdata['Pulse_rate'].value_counts()
# Out:
# 78.0     19
# 118.0    16
# 98.0     15
# 117.0    15
# 73.0     15
# 72.0     14
# 105.0    14
# 81.0     13
# 76.0     13
# 77.0     13
# 114.0    13
# 71.0     12
# 119.0    12
# 99.0     11
# 110.0    11
# 93.0     11
# 94.0     11
# 102.0    11
# 115.0    10
# 103.0    10
# 108.0    10
# 109.0    10
# 116.0    10
# 83.0     10
# 111.0    10
# 89.0     10
# 90.0      9
# 75.0      9
# 92.0      9
# 79.0      9
# 84.0      9
# 96.0      9
# 70.0      8
# 86.0      8
# 74.0      8
# 85.0      8
# 106.0     8
# 97.0      8
# 88.0      8
# 80.0      8
# 82.0      8
# 87.0      8
# 113.0     7
# 95.0      7
# 100.0     5
# 91.0      5
# 107.0     5
# 104.0     5
# 120.0     5
# 112.0     4
# 101.0     4
# Name: Pulse_rate, dtype: int64

# %%
# To know the stats about the dataset
labourdata.describe()
# Out:
#               Age  Experience  Total_working_hours  GSR_sensor  Pulse_rate  \
# count  500.000000  500.000000           500.000000   500.00000   500.00000
# mean    42.538000    5.160000             8.032000    30.96200    94.38400
# std     10.563509    4.200677             0.784989    12.17658    15.36883
# min     25.000000    0.000000             7.000000    10.00000    70.00000
# 25%     33.000000    1.000000             7.000000    19.75000    80.00000
# 50%     43.000000    4.000000             8.000000    32.00000    94.00000
# 75%     51.000000    8.000000             9.000000    42.00000   108.00000
# max     60.000000   18.000000             9.000000    50.00000   120.00000
#
#        Body_temperature  Calorie_brunt  Steps_walked
# count        500.000000     500.000000    500.000000
# mean          98.516000    3588.410000  11589.066000
# std            1.129733     867.202279   2027.183287
# min           97.000000    2007.000000   8023.000000
# 25%           98.000000    2848.750000   9687.000000
# 50%           98.500000    3618.000000  11675.000000
# 75%          100.000000    4393.750000  13354.000000
# max          100.000000    4999.000000  14989.000000

# %%
# Checking the Null Values in the Dataset
labourdata.isna().sum()
# Out:
# Age                    1
# Gender                 1
# Nationality            1
# Native_place           1
# Martial_status         1
# Designation            1
# Experience             1
# In_time                1
# Out_time               1
# Total_working_hours    1
# Site                   1
# GSR_sensor             1
# Pulse_rate             1
# Body_temperature       1
# Calorie_brunt          1
# Steps_walked           1
# Real_time_info         1
# Productivity           1
# dtype: int64

# %%
labourdata = labourdata.dropna()

# %%
labourdata.isna().sum()
# Out:
# Age                    0
# Gender                 0
# Nationality            0
# Native_place           0
# Martial_status         0
# Designation            0
# Experience             0
# In_time                0
# Out_time               0
# Total_working_hours    0
# Site                   0
# GSR_sensor             0
# Pulse_rate             0
# Body_temperature       0
# Calorie_brunt          0
# Steps_walked           0
# Real_time_info         0
# Productivity           0
# dtype: int64

# %%
# All null values are removed

# %%
# Checking the Duplicate Values in the Dataset
duplicate = labourdata.duplicated()
duplicate
sum(duplicate)
# Out:
# 0

# %%
# EXPLORATORY DATA ANALYSIS

# %%
# The Histogram of all The Numerical columns in combined
plt.figure()
labourdata.hist(figsize=(20,16),xrot=40)
plt.show()

# %%
# The For Loop to get the countplot of each column
for column in labourdata.select_dtypes(include='object'):
    if labourdata[column].nunique() < 10:
        sns.countplot(y=column,data=labourdata)
        plt.show()

# %%
# For loop to plot the boxplot of all numerical columns in one loop
columns = ['Age','Experience' ,'Body_temperature','Total_working_hours','GSR_sensor','Pulse_rate','Calorie_brunt','Steps_walked']
for col in columns:
    plt.figure(figsize=(8,8))
    sns.boxplot(labourdata[col])
    plt.show()

# %%
# Univarite Analysis
plt.figure()
sns.catplot(data=labourdata, x="Gender", y="Age", kind="box")
plt.show()

# %%
sns.catplot(data=labourdata, x="Gender", y="Experience", kind="box")

# %%
sns.catplot(data=labourdata, x="Gender", y="GSR_sensor", kind="box")

# %%
plt.figure()
sns.catplot(data=labourdata, x="Gender", y="Pulse_rate", kind="box")
plt.show()

# %%
sns.catplot(data=labourdata, x="Gender", y="Body_temperature", kind="box")

# %%
plt.figure(figsize=(10,7))
labourdata['Gender'].value_counts().plot(kind="pie", autopct="%.2f")
plt.show()

# %%
plt.figure(figsize=(19,13))
labourdata['Age'].value_counts().plot(kind="pie", autopct="%.2f")
plt.show()

# %%
plt.figure(figsize=(12,8))
labourdata['Nationality'].value_counts().plot(kind="pie", autopct="%.2f")
plt.show()

# %%
plt.figure(figsize=(10,7))
labourdata['Designation'].value_counts().plot(kind="pie", autopct="%.2f")
plt.show()

# %%
plt.figure(figsize=(18,15))
labourdata['Experience'].value_counts().plot(kind="pie", autopct="%.2f")
plt.show()

# %%
plt.figure(figsize=(15,11))
labourdata['Productivity'].value_counts().plot(kind="pie", autopct="%.2f")
plt.show()

# %%
plt.figure(figsize=(15,11))
labourdata['Site'].value_counts().plot(kind="pie", autopct="%.2f")
plt.show()

# %%
plt.figure(figsize=(21,13))
labourdata['Real_time_info'].value_counts().plot(kind="pie", autopct="%.2f")
plt.show()

# %%
plt.figure(figsize=(30,22))
labourdata['Pulse_rate'].value_counts().plot(kind="pie", autopct="%.2f")
plt.show()

# %%
plt.figure(figsize=(12,9))
labourdata['Martial_status'].value_counts().plot(kind="pie", autopct="%.2f")
plt.show()

# %%
plt.figure(figsize=(9,8))
sns.barplot(labourdata['Gender'], labourdata['Age'])
plt.show()

# %%
plt.figure(figsize=(12,9))
sns.barplot(labourdata['Age'], labourdata['Nationality'])
plt.show()

# %%
plt.figure(figsize=(8,7))
sns.barplot(labourdata['Gender'], labourdata['Pulse_rate'])
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.barplot(labourdata['Gender'], labourdata['Steps_walked'])
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.barplot(labourdata['Gender'], labourdata['Calorie_brunt'])
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.barplot(labourdata['Gender'], labourdata['Body_temperature'])
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.barplot(labourdata['Gender'], labourdata['GSR_sensor'])
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.barplot(labourdata['Gender'], labourdata['Total_working_hours'])
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.barplot(labourdata['Gender'], labourdata['Experience'])
plt.show()

# %%
plt.figure(figsize=(14,9))
sns.barplot(labourdata['Age'], labourdata['Steps_walked'])
plt.show()

# %%
plt.figure(figsize=(14,9))
sns.barplot(labourdata['Age'], labourdata['Calorie_brunt'])
plt.show()

# %%
plt.figure(figsize=(14,9))
sns.barplot(labourdata['Age'], labourdata['Body_temperature'])
plt.show()

# %%
plt.figure(figsize=(14,9))
sns.barplot(labourdata['Age'], labourdata['GSR_sensor'])
plt.show()

# %%
plt.figure(figsize=(14,9))
sns.barplot(labourdata['Nationality'], labourdata['Pulse_rate'])
plt.xticks(rotation=40)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14,9))
sns.barplot(labourdata['Nationality'], labourdata['Calorie_brunt'])
plt.xticks(rotation=40)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14,9))
sns.barplot(labourdata['Nationality'], labourdata['Steps_walked'])
plt.xticks(rotation=40)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14,9))
sns.barplot(labourdata['Nationality'], labourdata['Body_temperature'])
plt.xticks(rotation=40)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.barplot(labourdata['Experience'], labourdata['Gender'], hue = labourdata["Gender"])
plt.show()

# %%
plt.figure(figsize=(9,6))
sns.boxplot(labourdata['Age'], labourdata["Nationality"], labourdata["Gender"])
plt.yticks(rotation=26)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(16,10))
sns.boxplot(labourdata['Age'], labourdata["Nationality"], labourdata["Designation"])
plt.yticks(rotation=26)
plt.tight_layout()
plt.show()

# %%
labourdata.columns

sns.set_theme()
f, ax = plt.subplots(figsize=(12,10))
corr = labourdata.corr()
sns.heatmap(corr,
           xticklabels=corr.columns.values,
           yticklabels=corr.columns.values,cmap='spring_r')
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(labourdata, hue='Real_time_info')

# %%
# Dropping the Columns Which are Un-necessary
labourdata.drop(['Nationality','Martial_status','Designation','Experience','In_time','Out_time','Native_place','Site'],axis=1 ,inplace=True)

# %%
labourdata.dtypes
# Out:
# Age                    float64
# Gender                  object
# Total_working_hours    float64
# GSR_sensor             float64
# Pulse_rate             float64
# Body_temperature       float64
# Calorie_brunt          float64
# Steps_walked           float64
# Real_time_info          object
# Productivity            object
# dtype: object

# %%
labourdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  500 non-null    float64
#  1   Gender               500 non-null    object
#  2   Total_working_hours  500 non-null    float64
#  3   GSR_sensor           500 non-null    float64
#  4   Pulse_rate           500 non-null    float64
#  5   Body_temperature     500 non-null    float64
#  6   Calorie_brunt        500 non-null    float64
#  7   Steps_walked         500 non-null    float64
#  8   Real_time_info       500 non-null    object
#  9   Productivity         500 non-null    object
# dtypes: float64(7), object(3)
# memory usage: 43.0+ KB

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()

# %%
labourdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  500 non-null    float64
#  1   Gender               500 non-null    object
#  2   Total_working_hours  500 non-null    float64
#  3   GSR_sensor           500 non-null    float64
#  4   Pulse_rate           500 non-null    float64
#  5   Body_temperature     500 non-null    float64
#  6   Calorie_brunt        500 non-null    float64
#  7   Steps_walked         500 non-null    float64
#  8   Real_time_info       500 non-null    object
#  9   Productivity         500 non-null    object
# dtypes: float64(7), object(3)
# memory usage: 43.0+ KB

# %%
for i in (1,7,8):
    labourdata.iloc[:,i] = lb.fit_transform(labourdata.iloc[:,i])
labourdata.head()
# Out:
#     Age  Gender  Total_working_hours  GSR_sensor  Pulse_rate  \
# 0  34.0       1                  8.0        12.0        81.0
# 1  45.0       0                  7.0        18.0       105.0
# 2  44.0       1                  9.0        23.0        89.0
# 3  32.0       0                  8.0        14.0        90.0
# 4  49.0       1                  9.0        38.0        98.0
#
#    Body_temperature  Calorie_brunt  Steps_walked  Real_time_info Productivity
# 0             100.0         3690.0           293               1    Excellent
# 1              99.0         2525.0           304               1    Excellent
# 2              98.0         4895.0           426               1    Excellent
# 3              99.0         3538.0           134               1    Excellent
# 4              99.0         4723.0           126               1    Excellent

# %%
labourdata
# Out:
#       Age  Gender  Total_working_hours  GSR_sensor  Pulse_rate  \
# 0    34.0       1                  8.0        12.0        81.0
# 1    45.0       0                  7.0        18.0       105.0
# 2    44.0       1                  9.0        23.0        89.0
# 3    32.0       0                  8.0        14.0        90.0
# 4    49.0       1                  9.0        38.0        98.0
# ..    ...     ...                  ...         ...         ...
# 495  43.0       0                  7.0        23.0        77.0
# 496  57.0       1                  8.0        44.0       109.0
# 497  49.0       1                  9.0        44.0        89.0
# 498  46.0       1                  9.0        44.0        98.0
# 499  35.0       1                  8.0        29.0       114.0
#
#      Body_temperature  Calorie_brunt  Steps_walked  Real_time_info  \
# 0               100.0         3690.0           293               1
# 1                99.0         2525.0           304               1
# 2                98.0         4895.0           426               1
# 3                99.0         3538.0           134               1
# 4                99.0         4723.0           126               1
# ..                ...            ...           ...             ...
# 495              98.0         3914.0            57               1
# 496              97.0         2596.0           372               1
# 497             100.0         4617.0           241               1
# 498             100.0         3545.0           155               1
# 499              99.0         4657.0           333               1
#
#     Productivity
# 0      Excellent
# 1      Excellent
# 2      Excellent
# 3      Excellent
# 4      Excellent
# ..           ...
# 495         Good
# 496         Good
# 497         Good
# 498         Good
# 499         Good
#
# [500 rows x 10 columns]

# %%
labourdata.corr()
# Out:
#                           Age    Gender  Total_working_hours  GSR_sensor  \
# Age                  1.000000  0.041472             0.028854   -0.008971
# Gender               0.041472  1.000000             0.047406   -0.085499
# Total_working_hours  0.028854  0.047406             1.000000   -0.022935
# GSR_sensor          -0.008971 -0.085499            -0.022935    1.000000
# Pulse_rate           0.007131  0.000119             0.017584   -0.026961
# Body_temperature     0.031771  0.012923            -0.023176    0.037120
# Calorie_brunt        0.006422  0.054426            -0.038963    0.012658
# Steps_walked        -0.078644 -0.027089            -0.041367    0.002994
# Real_time_info       0.008328 -0.050036             0.024707    0.002050
#
#                      Pulse_rate  Body_temperature  Calorie_brunt  \
# Age                    0.007131          0.031771       0.006422
# Gender                 0.000119          0.012923       0.054426
# Total_working_hours    0.017584         -0.023176      -0.038963
# GSR_sensor            -0.026961          0.037120       0.012658
# Pulse_rate             1.000000         -0.035904       0.054108
# Body_temperature      -0.035904          1.000000       0.032136
# Calorie_brunt          0.054108          0.032136       1.000000
# Steps_walked           0.049996         -0.055908      -0.012635
# Real_time_info         0.049436          0.008584      -0.041089
#
#                      Steps_walked  Real_time_info
# Age                     -0.078644        0.008328
# Gender                  -0.027089       -0.050036
# Total_working_hours     -0.041367        0.024707
# GSR_sensor               0.002994        0.002050
# Pulse_rate               0.049996        0.049436
# Body_temperature        -0.055908        0.008584
# Calorie_brunt           -0.012635       -0.041089
# Steps_walked             1.000000       -0.028217
# Real_time_info          -0.028217        1.000000

# %%
X = labourdata.loc[:, labourdata.columns!="Productivity"]
X
# Out:
#       Age  Gender  Total_working_hours  GSR_sensor  Pulse_rate  \
# 0    34.0       1                  8.0        12.0        81.0
# 1    45.0       0                  7.0        18.0       105.0
# 2    44.0       1                  9.0        23.0        89.0
# 3    32.0       0                  8.0        14.0        90.0
# 4    49.0       1                  9.0        38.0        98.0
# ..    ...     ...                  ...         ...         ...
# 495  43.0       0                  7.0        23.0        77.0
# 496  57.0       1                  8.0        44.0       109.0
# 497  49.0       1                  9.0        44.0        89.0
# 498  46.0       1                  9.0        44.0        98.0
# 499  35.0       1                  8.0        29.0       114.0
#
#      Body_temperature  Calorie_brunt  Steps_walked  Real_time_info
# 0               100.0         3690.0           293               1
# 1                99.0         2525.0           304               1
# 2                98.0         4895.0           426               1
# 3                99.0         3538.0           134               1
# 4                99.0         4723.0           126               1
# ..                ...            ...           ...             ...
# 495              98.0         3914.0            57               1
# 496              97.0         2596.0           372               1
# 497             100.0         4617.0           241               1
# 498             100.0         3545.0           155               1
# 499              99.0         4657.0           333               1
#
# [500 rows x 9 columns]

# %%
Y = labourdata["Productivity"]
Y
# Out:
# 0      Excellent
# 1      Excellent
# 2      Excellent
# 3      Excellent
# 4      Excellent
#          ...
# 495         Good
# 496         Good
# 497         Good
# 498         Good
# 499         Good
# Name: Productivity, Length: 500, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.20, random_state = 21)

# %%
from sklearn.preprocessing import StandardScaler

# Standardization technique is used
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train.shape, X_test.shape
# Out:
# ((400, 9), (100, 9))

# %%
Y_train.shape, Y_test.shape
# Out:
# ((400,), (100,))

# %%
# Model Building

# %%
# KNN
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
knn = KNeighborsClassifier(n_neighbors = 21)

# %%
knn.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=21)

# %%
pred = knn.predict(X_test)
pred
# Out:
# array(['Good', 'Good', 'Excellent', 'Excellent', 'Excellent', 'Excellent',
#        'Good', 'Excellent', 'Excellent', 'Good', 'Good', 'Excellent',
#        'Excellent', 'Excellent', 'Excellent', 'Excellent', 'Excellent',
#        'Excellent', 'Excellent', 'Excellent', 'Excellent', 'Good',
#        'Excellent', 'Good', 'Excellent', 'Excellent', 'Excellent',
#        'Excellent', 'Good', 'Excellent', 'Good', 'Excellent', 'Good',
#        'Excellent', 'Excellent', 'Excellent', 'Good', 'Excellent',
#        'Excellent', 'Excellent', 'Good', 'Excellent', 'Excellent',
#        'Excellent', 'Excellent', 'Excellent', 'Excellent', 'Excellent',
#        'Good', 'Good', 'Good', 'Good', 'Excellent', 'Good', 'Excellent',
#        'Excellent', 'Excellent', 'Good', 'Good', 'Excellent', 'Good',
#        'Good', 'Excellent', 'Excellent', 'Excellent', 'Excellent', 'Good',
#        'Excellent', 'Good', 'Excellent', 'Excellent', 'Excellent',
#        'Excellent', 'Excellent', 'Excellent', 'Good', 'Excellent',
#        'Excellent', 'Excellent', 'Good', 'Excellent', 'Excellent', 'Good',
#        'Excellent', 'Excellent', 'Excellent', 'Excellent', 'Good', 'Good',
#        'Excellent', 'Excellent', 'Good', 'Good', 'Excellent', 'Excellent',
#        'Good', 'Excellent', 'Good', 'Excellent', 'Good'], dtype=object)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(Y_test, pred))
pd.crosstab(Y_test, pred, rownames = ['Actual'], colnames= ['Predictions']) 


# error on train data
pred_train = knn.predict(X_train)
print(accuracy_score(Y_train, pred_train))
pd.crosstab(Y_train, pred_train, rownames=['Actual'], colnames = ['Predictions'])
# Out:
# 0.46
# 0.59
# Predictions  Excellent  Good
# Actual
# Bad                  3     3
# Excellent          139    60
# Good                98    97

# %%
# Logistic regression
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
lr = LogisticRegression()

# %%
lr.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
Y_pred = lr.predict(X_test)

# %%
lr_train_acc = accuracy_score(Y_train, lr.predict(X_train))
lr_test_acc = accuracy_score(Y_test, Y_pred)

# %%
print(f"Training Accuracy of Logistic Regression Model is {lr_train_acc}")
print(f"Test Accuracy of Logistic Regression Model is {lr_test_acc}")
# Out:
# Training Accuracy of Logistic Regression Model is 0.5275
# Test Accuracy of Logistic Regression Model is 0.43

# %%
# Desicion Tree
from sklearn.tree import DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier()

# %%
dtc.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier()

# %%
Y_pred = dtc.predict(X_test)

# %%
dtc_train_acc = accuracy_score(Y_train, dtc.predict(X_train))
dtc_test_acc = accuracy_score(Y_test, Y_pred)

# %%
print(f"Training Accuracy of Decision Tree Model is {dtc_train_acc}")
print(f"Test Accuracy of Decision Tree Model is {dtc_test_acc}")
# Out:
# Training Accuracy of Decision Tree Model is 1.0
# Test Accuracy of Decision Tree Model is 0.51

# %%
# Naive bias
from sklearn.naive_bayes import GaussianNB

# %%
gnb = GaussianNB()

# %%
gnb.fit(X_train, Y_train)
# Out:
# GaussianNB()

# %%
Y_pred = gnb.predict(X_test)

# %%
gnb_train_acc = accuracy_score(Y_train, gnb.predict(X_train))
gnb_test_acc = accuracy_score(Y_test, Y_pred)

# %%
print(f"Training Accuracy of XGB Model is {gnb_train_acc}")
print(f"Test Accuracy of XGB Model is {gnb_test_acc}")
# Out:
# Training Accuracy of XGB Model is 0.5175
# Test Accuracy of XGB Model is 0.46

# %%
# Multi-Layer Perceptron Classifier

from sklearn.neural_network import MLPClassifier

# %%
ANN = MLPClassifier(hidden_layer_sizes=(100,100,100),batch_size=10,learning_rate_init=0.01,max_iter=2000,random_state=10)

# %%
ANN.fit(X_train,Y_train)
# Out:
# MLPClassifier(batch_size=10, hidden_layer_sizes=(100, 100, 100),
#               learning_rate_init=0.01, max_iter=2000, random_state=10)

# %%
Y_pred = ANN.predict(X_test)

# %%
ann_train_acc = accuracy_score(Y_train, ANN.predict(X_train))
ann_test_acc = accuracy_score(Y_test, Y_pred)

# %%
print(f"Training Accuracy of ANN Model is {ann_train_acc}")
print(f"Test Accuracy of ANN Model is {ann_train_acc}")
# Out:
# Training Accuracy of ANN Model is 0.925
# Test Accuracy of ANN Model is 0.925

# %%
# 5.Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier

# %%
rand_clf = RandomForestClassifier(criterion = 'gini', max_depth = 8, max_features = 'sqrt', min_samples_leaf = 4, min_samples_split = 5, n_estimators = 150)

# %%
rand_clf.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(max_depth=8, max_features='sqrt', min_samples_leaf=4,
#                        min_samples_split=5, n_estimators=150)

# %%
Y_pred = rand_clf.predict(X_test)

# %%
rand_clf_train_acc = accuracy_score(Y_train, rand_clf.predict(X_train))
rand_clf_test_acc = accuracy_score(Y_test, Y_pred)

# %%
print(f"Training Accuracy of Random Forest Classifier Model is {rand_clf_train_acc}")
print(f"Test Accuracy of Random Forest Classifier Model is {rand_clf_test_acc}")
# Out:
# Training Accuracy of Random Forest Classifier Model is 0.91
# Test Accuracy of Random Forest Classifier Model is 0.53

# %%
# Support Vector Classification

from sklearn.svm import SVC

# %%
SVM = SVC(kernel='rbf', C=100, random_state=10).fit(X_train,Y_train)

# %%
SVM.fit(X_train, Y_train)
# Out:
# SVC(C=100, random_state=10)

# %%
Y_pred = SVM.predict(X_test)

# %%
svm_train_acc = accuracy_score(Y_train, SVM.predict(X_train))
svm_test_acc = accuracy_score(Y_test, Y_pred)

# %%
print(f"Training Accuracy of Support Vector Classification Model is {svm_train_acc}")
print(f"Test Accuracy of Support Vector Classification Model is {svm_test_acc}")
# Out:
# Training Accuracy of Support Vector Classification Model is 0.99
# Test Accuracy of Support Vector Classification Model is 0.49
